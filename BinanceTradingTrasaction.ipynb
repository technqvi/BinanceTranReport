# %%
import pandas as pd
from datetime import datetime
from dotenv import dotenv_values
from binance.client import Client

# %%
#https://python-binance.readthedocs.io/en/latest/binance.html?highlight=get_avg_price#binance.client.Client.get_avg_price
#https://binance-docs.github.io/apidocs/spot/en/#current-average-price
#https://python-binance.readthedocs.io/en/latest/_modules/binance/client.html?highlight=get_avg_price#

# %%
q_start='2022-05-30 01:00'
q_end='2022-06-03'

# %%
def replaceString(txt):
  specialChars =[' ',':'] 
  for specialChar in specialChars:
    txt = txt.replace(specialChar, '_')
  return txt 

title_start=replaceString(q_start)
title_end=replaceString(q_end)
print(title_start)
print(title_end)
# Out:
# 2022-05-30_01_00
# 2022-06-03

# %%
root_path=r'D:\BC-World\CryptoTrans\BS-Trade'

buildtime = datetime.now().strftime('%d%m%y_%H%M')

# copy file from last export to  Binance Trade History_From2022-02-01.xlsx

trans_path=f'{root_path}\\Master\\Raw_BinanceTradeHistory.xlsx'
add_path=f'{root_path}\\Master\\Addtional_TranancTrade OutOfBN-Trade.xlsx'
master_path=f'{root_path}\\Master\\Master_BinanceTradeHistory.xlsx'


if q_start!='' and q_end!='':
    
    tran2s_path2=f'{root_path}\\THistReport_{title_start}-{title_end}_At_{buildtime}.xlsx'
else:
    tran2s_path2=f'{root_path}\\Report\\THistReport_At_{buildtime}.xlsx'
    
print(tran2s_path2)




coinPairList=['USDT','BUSD','USDC','DAI','']

fund_path=r'D:\AB_DB\AB_Cryptos_Files\database\crypto_db.db'

path_config=r'D:\AB_DB\Script_ImportData'

colsList=['DateTime(UTC)','Symbol','Type','Price','Amount','Total']
colsDelete=['Date(UTC)','Market','Fee','Fee Coin']

main_pair='BUSD'
#colsList=['DateTime(UTC)','Symbol','PairCoin','Market','Type','Price','Amount','Total','Fee','Fee Coin']
# Out:
# D:\BC-World\CryptoTrans\BS-Trade\THistReport_2022-05-30_01_00-2022-06-03_At_020622_1428.xlsx

# %%
config_values= dotenv_values(dotenv_path=f'{path_config}\\.env')
api_key = config_values['bn_key']
api_secret =config_values['bn_secrete']
client=Client(api_key,api_secret)

# %%
df_trasns=pd.read_excel(trans_path,engine='openpyxl')
df_trasns['DateTime(UTC)']=pd.to_datetime(df_trasns['Date(UTC)'],format='%Y-%m-%d %H:%M:%S')
df_trasns.info()
df_trasns.tail(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 379 entries, 0 to 378
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date(UTC)      379 non-null    object
#  1   Market         379 non-null    object
#  2   Type           379 non-null    object
#  3   Price          379 non-null    float64
#  4   Amount         379 non-null    float64
#  5   Total          379 non-null    float64
#  6   Fee            379 non-null    float64
#  7   Fee Coin       371 non-null    object
#  8   DateTime(UTC)  379 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 26.8+ KB
#                Date(UTC)     Market  Type      Price    Amount      Total  \
# 359  2022-06-01 04:02:55  MATICBUSD   BUY      0.650  16.60000  10.790000
# 360  2022-05-31 14:06:39    ETHBUSD   BUY   1931.000   0.00730  14.096300
# 361  2022-05-31 13:40:02    SOLBUSD   BUY     45.250   0.31000  14.027500
# 362  2022-05-31 06:38:50    ETHBUSD   BUY   1961.000   0.00860  16.864600
# 363  2022-05-31 04:23:34   USDCBUSD  SELL      1.000  50.01000  50.010000
# 364  2022-05-30 13:20:01    SOLBUSD   BUY     45.000   0.31000  13.950000

# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateTime(UTC)  15 non-null     datetime64[ns]
#  1   Symbol         15 non-null     object
#  2   Type           15 non-null     object
#  3   Price          15 non-null     float64
#  4   Amount         15 non-null     float64
#  5   Total          15 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 848.0+ bytes
#          DateTime(UTC) Symbol  Type       Price     Amount      Total
# 10 2022-03-07 08:00:00   AVAX  SELL   72.090000   0.950000  68.485500
# 11 2022-03-07 08:00:00   AVAX  SELL   75.920000   0.662663  50.309348
# 12 2022-05-10 08:00:00    SOL  SELL   67.050000   0.200000  13.410000
# 13 2022-05-10 14:00:00    UST  SELL    0.901250  10.000000   9.012500
# 14 2022-05-25 14:00:00    BNB   BUY  334.979212   0.050750  17.000195

# %%
if q_start!='' and q_end!='':
 df_addTran=df_addTran[ (df_addTran['DateTime(UTC)']>=q_start) & (df_addTran['DateTime(UTC)']<=q_end)]
 print(df_addTran.info())
 print(df_addTran)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateTime(UTC)  0 non-null      datetime64[ns]
#  1   Symbol         0 non-null      object
#  2   Type           0 non-null      object
#  3   Price          0 non-null      float64
#  4   Amount         0 non-null      float64
#  5   Total          0 non-null      float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 0.0+ bytes
# None
# Empty DataFrame
# Columns: [DateTime(UTC), Symbol, Type, Price, Amount, Total]
# Index: []

# %%
def replance_pair_coin_with_empty(x):
   for pair in coinPairList:
    if x.endswith(pair):
        x=x.replace(pair,'')
        
   return x     
def sete_pair_coin_with(x):
   for pair in coinPairList:
    if x.endswith(pair):
        x=pair       
   return x     
print("List All transaction in Binance")           
df_trasns['Symbol']=df_trasns['Market']               
df_trasns['Symbol']=df_trasns['Market'].apply( replance_pair_coin_with_empty)
# df_trasns['PairCoin']=df_trasns['Market'].apply( sete_pair_coin_with)

# exclude stablecoin
df_trasns=df_trasns[ ~df_trasns['Symbol'] .isin(coinPairList)]


df_trasns=df_trasns.drop(columns=colsDelete)
df_trasns=df_trasns[colsList]
df_trasns.info()
df_trasns
# Out:
# List All transaction in Binance
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 354 to 378
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateTime(UTC)  23 non-null     datetime64[ns]
#  1   Symbol         23 non-null     object
#  2   Type           23 non-null     object
#  3   Price          23 non-null     float64
#  4   Amount         23 non-null     float64
#  5   Total          23 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 1.3+ KB
#           DateTime(UTC) Symbol  Type      Price    Amount      Total
# 354 2022-06-01 14:36:44  MATIC   BUY      0.625  22.40000  14.000000
# 355 2022-06-01 14:36:22    BNB   BUY    312.500   0.03800  11.875000
# 356 2022-06-01 14:35:06    BTC   BUY  31222.000   0.00038  11.864360
# 357 2022-06-01 14:35:06    BTC   BUY  31222.000   0.00035  10.927700
# 358 2022-06-01 04:09:20    SOL  SELL     44.550   0.23000  10.246500
# 361 2022-05-31 13:40:02    SOL   BUY     45.250   0.31000  14.027500
# 362 2022-05-31 06:38:50    ETH   BUY   1961.000   0.00860  16.864600
# 364 2022-05-30 13:20:01    SOL   BUY     45.000   0.31000  13.950000
# 365 2022-05-30 12:28:50    ETH   BUY   1881.000   0.00750  14.107500
# 366 2022-05-30 12:19:31    BNB   BUY    319.100   0.04700  14.997700
# 368 2022-05-30 12:14:35    BTC   BUY  30741.130   0.00045  13.833509
# 367 2022-05-30 12:14:35    BTC   BUY  30741.190   0.00014   4.303767
# 369 2022-05-30 12:11:21    SOL   BUY     46.180   0.23000  10.621400

# %%
if len(df_trasns.index)==0:
    print("No record to summarize tradig transaction")
    quit()

# %%
# symbol="SOL"
# xxx=df_trasns.query("Symbol==@symbol")
# xxx
print("Show dupplicated record")
duplicateRows = df_trasns[df_trasns.duplicated(keep=False)]
print(duplicateRows.info())
duplicateRows
# Out:
# Show dupplicated record
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 354 to 359
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateTime(UTC)  12 non-null     datetime64[ns]
#  1   Symbol         12 non-null     object
#  2   Type           12 non-null     object
#  3   Price          12 non-null     float64
#  4   Amount         12 non-null     float64
#  5   Total          12 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 672.0+ bytes
# None
#           DateTime(UTC) Symbol  Type      Price    Amount     Total
# 354 2022-06-01 14:36:44  MATIC   BUY      0.625  22.40000  14.00000
# 373 2022-06-01 14:36:44  MATIC   BUY      0.625  22.40000  14.00000
# 374 2022-06-01 14:36:22    BNB   BUY    312.500   0.03800  11.87500
# 355 2022-06-01 14:36:22    BNB   BUY    312.500   0.03800  11.87500
# 356 2022-06-01 14:35:06    BTC   BUY  31222.000   0.00038  11.86436
# 357 2022-06-01 14:35:06    BTC   BUY  31222.000   0.00035  10.92770
# 376 2022-06-01 14:35:06    BTC   BUY  31222.000   0.00035  10.92770
# 375 2022-06-01 14:35:06    BTC   BUY  31222.000   0.00038  11.86436
# 358 2022-06-01 04:09:20    SOL  SELL     44.550   0.23000  10.24650
# 377 2022-06-01 04:09:20    SOL  SELL     44.550   0.23000  10.24650
# 378 2022-06-01 04:02:55  MATIC   BUY      0.650  16.60000  10.79000
# 359 2022-06-01 04:02:55  MATIC   BUY      0.650  16.60000  10.79000

# %%
required_drop_dup=True

# %%
if required_drop_dup:
    df_trasns=df_trasns.drop_duplicates(keep='first')
    df_trasns.info()
    df_trasns.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 371 to 369
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DateTime(UTC)  17 non-null     datetime64[ns]
#  1   Symbol         17 non-null     object
#  2   Type           17 non-null     object
#  3   Price          17 non-null     float64
#  4   Amount         17 non-null     float64
#  5   Total          17 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(2)
# memory usage: 952.0+ bytes

# %%
duplicateRows = df_trasns[df_trasns.duplicated()]
if(len(duplicateRows)>0):
    raise ("Keep having duplicated rows")
else:
    print("no duplicated rows")
# Out:
# no duplicated rows

# %%
print("Agg transaction")
groupby_cols=['Symbol','Type']
agg_cols=['Amount','Total']
df_summary=df_trasns.groupby(groupby_cols,as_index=False)[agg_cols].sum()
df_summary['AvgPrice']=df_summary['Total']/df_summary['Amount']
df_summary=df_summary.round(5)
df_summary
# Out:
# Agg transaction
#   Symbol  Type    Amount     Total     AvgPrice
# 0    BNB   BUY   0.08500  26.87270    316.14941
# 1    BTC   BUY   0.00168  51.92014  30904.84232
# 2    BTC  SELL   0.00033  10.23792  31024.00000
# 3    ETH   BUY   0.02340  45.06840   1926.00000
# 4  MATIC   BUY  39.00000  24.79000      0.63564
# 5    SOL   BUY   0.85000  38.59890     45.41047
# 6    SOL  SELL   0.23000  10.24650     44.55000

# %%
df_net_summary=df_summary.copy()
df_net_summary=df_summary.drop(columns=['AvgPrice'])
def negative_val_for_sell(item):
    if item['Type']=='SELL':
        item['Amount']=item['Amount']*-1
        item['Total']=item['Total']*-1
        
    return item    
df_net_summary=df_net_summary.apply(negative_val_for_sell,axis=1) 
df_net_summary
# Out:
#   Symbol  Type    Amount     Total
# 0    BNB   BUY   0.08500  26.87270
# 1    BTC   BUY   0.00168  51.92014
# 2    BTC  SELL  -0.00033 -10.23792
# 3    ETH   BUY   0.02340  45.06840
# 4  MATIC   BUY  39.00000  24.79000
# 5    SOL   BUY   0.85000  38.59890
# 6    SOL  SELL  -0.23000 -10.24650

# %%
def get_current_price(item):
    symbol_pair=f"{item['Symbol']}{main_pair}"
    current_price =float( client.get_symbol_ticker(symbol=symbol_pair)['price'])
    #current_price_Avg = client.get_avg_price(symbol="BTCUSDT")
    current_price=round(current_price,5)
    return current_price

# %%
groupby_cols=['Symbol']
agg_cols=['Amount','Total']
dfNet=df_net_summary.groupby(groupby_cols,as_index=False)[agg_cols].sum()
dfNet['Price']=dfNet.apply(get_current_price,axis=1)

dfNet['CurrentVal']=dfNet['Price']*dfNet['Amount']

dfNet['MyVal']=dfNet['CurrentVal']-dfNet['Total']

dfNet=dfNet[['Symbol','Amount','Price','CurrentVal','MyVal']]

dfNet
# Out:
#   Symbol    Amount      Price  CurrentVal     MyVal
# 0    BNB   0.08500    303.600   25.806000 -1.066700
# 1    BTC   0.00135  30001.440   40.501944 -1.180276
# 2    ETH   0.02340   1832.790   42.887286 -2.181114
# 3  MATIC  39.00000      0.605   23.595000 -1.195000
# 4    SOL   0.62000     39.840   24.700800 -3.651600

# %%
srNet_Sum=dfNet[['CurrentVal','MyVal']].sum()
dfNet_Sum=srNet_Sum.to_frame("Value")

# %%
dfNet_Sum.reset_index(inplace=True)

dfNet_Sum
# Out:
#         index      Value
# 0  CurrentVal  157.49103
# 1       MyVal   -9.27469

# %%
df_totalBuySell=df_summary.groupby(['Type'],as_index=False)[['Total']].sum()

# %%
df_totalBuySell
# Out:
#    Type      Total
# 0   BUY  187.25014
# 1  SELL   20.48442

# %%
#df_trasns.to_excel(tran2s_path2,index=False)
writer=pd.ExcelWriter(tran2s_path2,engine='xlsxwriter') 

df_totalBuySell.to_excel(writer, sheet_name="Total")
dfNet_Sum.to_excel(writer, sheet_name="PossitionVal",index=False) 
dfNet.to_excel(writer, sheet_name="NetSummary",index=False)   
df_summary.to_excel(writer, sheet_name="SummaryBuySell",index=False)   
df_trasns.to_excel(writer, sheet_name="Detail",index=False)

writer.save()

# %%
# https://exchangeratesapi.io/documentation/

# %%
if q_start=='' and q_end=='':
 df_trasns.to_excel(master_path,sheet_name='Master_BuySell',index=False)
